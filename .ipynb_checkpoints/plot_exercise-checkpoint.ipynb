# %%
# %matplotlib notebook

# %%
# import libraries
import numpy as np
import scipy.stats
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create a normal (Gaussian) distribution
# between -20 and 20 with .001 step size
x = np.arange(-20, 20, 0.001)
# mean
u = 2
# standard deviation
sigma = 10
# probability density function for normal distribution
y = scipy.stats.norm.pdf(x, u, sigma)

# %%
# plot the normal distribution
plt.plot(y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# load CSV data into Pandas DataFrame
df = pd.read_csv('beijing_air_quality_data.csv',
                 parse_dates=['utc_time'])

# %%
# plot temperature series
s = df['temperature']
s.plot(figure=plt.figure())
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# plot temperature histogram
# Hint: call hist()
fig = plt.figure()
axis1 = fig.add_subplot(1,1,1)
axis1.hist(s,bins=10,color='k',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  12.,  222., 1927., 4994., 5310., 6310., 4988., 3868., 1834.,
#          775.]),
#  array([ 5. ,  8.1, 11.2, 14.3, 17.4, 20.5, 23.6, 26.7, 29.8, 32.9, 36. ]),
#  <BarContainer object of 10 artists>)
